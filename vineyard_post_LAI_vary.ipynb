# %%
import numpy as np
import scipy as spy
import scipy.integrate
import loadData as ld
import matplotlib.pyplot as plt
from IPython.display import HTML
import matplotlib.cm as cm
from matplotlib.colors import Normalize
# %matplotlib inline
axl_font_sz = 16;
fwidth = 4.0; fheight = fwidth/1.2;
nframe = 1;

# %%
master_dir_L1A0 = "/home/ahsan/LAI_1_16_rows_0/"
inpara_L1A0 = ld.readInput(master_dir_L1A0+"input/LESinputs.txt");
au_L1A0 = ld.loadBin(master_dir_L1A0+"output/au.bin", inpara_L1A0['Nz']);
av_L1A0 = ld.loadBin(master_dir_L1A0+"output/av.bin", inpara_L1A0['Nz']);
auu_L1A0 = ld.loadBin(master_dir_L1A0+"output/u2.bin", inpara_L1A0['Nz']);
avv_L1A0 = ld.loadBin(master_dir_L1A0+"output/v2.bin", inpara_L1A0['Nz']);
aww_L1A0 = ld.loadBin(master_dir_L1A0+"output/w2.bin", inpara_L1A0['Nz']);
auw_L1A0 = ld.loadBin(master_dir_L1A0+"output/auw.bin", inpara_L1A0['Nz']);
atxz_L1A0 = ld.loadBin(master_dir_L1A0+"output/atxz.bin", inpara_L1A0['Nz']);
avw_L1A0 = ld.loadBin(master_dir_L1A0+"output/avw.bin", inpara_L1A0['Nz']);
atyz_L1A0 = ld.loadBin(master_dir_L1A0+"output/atyz.bin", inpara_L1A0['Nz']);
ustar_L1A0_planeavg = ((auw_L1A0+atxz_L1A0)**2 + (avw_L1A0+atyz_L1A0)**2)**(0.25);

master_dir_L4A0 = "/home/ahsan/LAI_4_16_rows_0/"
inpara_L4A0 = ld.readInput(master_dir_L4A0+"input/LESinputs.txt");
au_L4A0 = ld.loadBin(master_dir_L4A0+"output/au.bin", inpara_L4A0['Nz']);
av_L4A0 = ld.loadBin(master_dir_L4A0+"output/av.bin", inpara_L4A0['Nz']);
auu_L4A0 = ld.loadBin(master_dir_L4A0+"output/u2.bin", inpara_L4A0['Nz']);
avv_L4A0 = ld.loadBin(master_dir_L4A0+"output/v2.bin", inpara_L4A0['Nz']);
aww_L4A0 = ld.loadBin(master_dir_L4A0+"output/w2.bin", inpara_L4A0['Nz']);
auw_L4A0 = ld.loadBin(master_dir_L4A0+"output/auw.bin", inpara_L4A0['Nz']);
atxz_L4A0 = ld.loadBin(master_dir_L4A0+"output/atxz.bin", inpara_L4A0['Nz']);
avw_L4A0 = ld.loadBin(master_dir_L4A0+"output/avw.bin", inpara_L4A0['Nz']);
atyz_L4A0 = ld.loadBin(master_dir_L4A0+"output/atyz.bin", inpara_L4A0['Nz']);
ustar_L4A0_planeavg = ((auw_L4A0+atxz_L4A0)**2 + (avw_L4A0+atyz_L4A0)**2)**(0.25);

master_dir_L1A45 = "/home/ahsan/LAI_1_16_rows_45/"
inpara_L1A45 = ld.readInput(master_dir_L1A45+"input/LESinputs.txt");
au_L1A45 = ld.loadBin(master_dir_L1A45+"output/au.bin", inpara_L1A45['Nz']);
av_L1A45 = ld.loadBin(master_dir_L1A45+"output/av.bin", inpara_L1A45['Nz']);
auu_L1A45 = ld.loadBin(master_dir_L1A45+"output/u2.bin", inpara_L1A45['Nz']);
avv_L1A45 = ld.loadBin(master_dir_L1A45+"output/v2.bin", inpara_L1A45['Nz']);
aww_L1A45 = ld.loadBin(master_dir_L1A45+"output/w2.bin", inpara_L1A45['Nz']);
auw_L1A45 = ld.loadBin(master_dir_L1A45+"output/auw.bin", inpara_L1A45['Nz']);
atxz_L1A45 = ld.loadBin(master_dir_L1A45+"output/atxz.bin", inpara_L1A45['Nz']);
avw_L1A45 = ld.loadBin(master_dir_L1A45+"output/avw.bin", inpara_L1A45['Nz']);
atyz_L1A45 = ld.loadBin(master_dir_L1A45+"output/atyz.bin", inpara_L1A45['Nz']);
ustar_L1A45_planeavg = ((auw_L1A45+atxz_L1A45)**2 + (avw_L1A0+atyz_L1A45)**2)**(0.25);

master_dir_L4A45 = "/home/ahsan/LAI_4_16_rows_45/"
inpara_L4A45 = ld.readInput(master_dir_L4A45+"input/LESinputs.txt");
au_L4A45 = ld.loadBin(master_dir_L4A45+"output/au.bin", inpara_L4A0['Nz']);
av_L4A45 = ld.loadBin(master_dir_L4A45+"output/av.bin", inpara_L4A0['Nz']);
auu_L4A45 = ld.loadBin(master_dir_L4A45+"output/u2.bin", inpara_L4A0['Nz']);
avv_L4A45 = ld.loadBin(master_dir_L4A45+"output/v2.bin", inpara_L4A0['Nz']);
aww_L4A45 = ld.loadBin(master_dir_L4A45+"output/w2.bin", inpara_L4A0['Nz']);
auw_L4A45 = ld.loadBin(master_dir_L4A45+"output/auw.bin", inpara_L4A0['Nz']);
atxz_L4A45 = ld.loadBin(master_dir_L4A45+"output/atxz.bin", inpara_L4A0['Nz']);
avw_L4A45 = ld.loadBin(master_dir_L4A45+"output/avw.bin", inpara_L4A0['Nz']);
atyz_L4A45 = ld.loadBin(master_dir_L4A45+"output/atyz.bin", inpara_L4A0['Nz']);
ustar_L4A45_planeavg = ((auw_L4A45+atxz_L4A45)**2 + (avw_L4A45+atyz_L4A45)**2)**(0.25);

# %%
time_steps_run = au_L1A0.shape[0]*inpara_L1A0['p_count'];
print("Total number of time steps simulation ran for: ", time_steps_run);
physical_time_run = time_steps_run * inpara_L1A0['dt'];
print("Physical time period of simulation(min):{0:2.2f}".format(physical_time_run/60.0));
# time steps corresponding to 5 minutes
set_min_steps = int(10 * 60 / inpara_L1A0['dt']/inpara_L1A0['p_count']);
z_u = np.linspace(0.5*inpara_L1A0['dz'], inpara_L1A0['l_z'], inpara_L1A0['Nz']);
z_w = np.linspace(0.0*inpara_L1A0['dz'], inpara_L1A0['l_z'], inpara_L1A0['Nz']);
time_values = np.arange(0,ustar_L1A0_planeavg.shape[0])*inpara_L1A0['p_count']*inpara_L1A0['dt'];
# Out:
# Total number of time steps simulation ran for:  1200000
# Physical time period of simulation(min):20.00

# %%
stavg_au_L1A0 = np.mean(au_L1A0[-set_min_steps:-1,:], axis=0);
stavg_av_L1A0 = np.mean(av_L1A0[-set_min_steps:-1,:], axis=0);
stavg_auu_L1A0 = np.mean(auu_L1A0[-set_min_steps:-1,:], axis=0);
stavg_avv_L1A0 = np.mean(avv_L1A0[-set_min_steps:-1,:], axis=0);
stavg_aww_L1A0 = np.mean(aww_L1A0[-set_min_steps:-1,:], axis=0);
stavg_auw_L1A0 = np.mean(auw_L1A0[-set_min_steps:-1,:], axis=0);
stavg_atxz_L1A0 = np.mean(atxz_L1A0[-set_min_steps:-1,:], axis=0);
stavg_avw_L1A0 = np.mean(avw_L1A0[-set_min_steps:-1,:], axis=0);
stavg_atyz_L1A0 = np.mean(atyz_L1A0[-set_min_steps:-1,:], axis=0);
ustar_L1A0 = ((stavg_auw_L1A0+stavg_atxz_L1A0)**2 + (stavg_avw_L1A0+stavg_atyz_L1A0)**2)**(0.25);
ustar_L1A0_max = ustar_L1A0.max()
MSpeed_L1A0 = np.sqrt(stavg_au_L1A0**2 + stavg_av_L1A0**2);

stavg_au_L4A0 = np.mean(au_L4A0[-set_min_steps:-1,:], axis=0);
stavg_av_L4A0 = np.mean(av_L4A0[-set_min_steps:-1,:], axis=0);
stavg_auu_L4A0 = np.mean(auu_L4A0[-set_min_steps:-1,:], axis=0);
stavg_avv_L4A0 = np.mean(avv_L4A0[-set_min_steps:-1,:], axis=0);
stavg_aww_L4A0 = np.mean(aww_L4A0[-set_min_steps:-1,:], axis=0);
stavg_auw_L4A0 = np.mean(auw_L4A0[-set_min_steps:-1,:], axis=0);
stavg_atxz_L4A0 = np.mean(atxz_L4A0[-set_min_steps:-1,:], axis=0);
stavg_avw_L4A0 = np.mean(avw_L4A0[-set_min_steps:-1,:], axis=0);
stavg_atyz_L4A0 = np.mean(atyz_L4A0[-set_min_steps:-1,:], axis=0);
ustar_L4A0 = ((stavg_auw_L4A0+stavg_atxz_L4A0)**2 + (stavg_avw_L4A0+stavg_atyz_L4A0)**2)**(0.25);
ustar_L4A0_max = ustar_L4A0.max()
MSpeed_L4A0 = np.sqrt(stavg_au_L4A0**2 + stavg_av_L4A0**2);

stavg_au_L1A45 = np.mean(au_L1A45[-set_min_steps:-1,:], axis=0);
stavg_av_L1A45 = np.mean(av_L1A45[-set_min_steps:-1,:], axis=0);
stavg_auu_L1A45 = np.mean(auu_L1A45[-set_min_steps:-1,:], axis=0);
stavg_avv_L1A45 = np.mean(avv_L1A45[-set_min_steps:-1,:], axis=0);
stavg_aww_L1A45 = np.mean(aww_L1A45[-set_min_steps:-1,:], axis=0);
stavg_auw_L1A45 = np.mean(auw_L1A45[-set_min_steps:-1,:], axis=0);
stavg_atxz_L1A45 = np.mean(atxz_L1A45[-set_min_steps:-1,:], axis=0);
stavg_avw_L1A45 = np.mean(avw_L1A45[-set_min_steps:-1,:], axis=0);
stavg_atyz_L1A45 = np.mean(atyz_L1A45[-set_min_steps:-1,:], axis=0);
ustar_L1A45 = ((stavg_auw_L1A45+stavg_atxz_L1A45)**2 + (stavg_avw_L1A45+stavg_atyz_L1A45)**2)**(0.25);
ustar_L1A45_max = ustar_L1A45.max()
MSpeed_L1A45 = np.sqrt(stavg_au_L1A45**2 + stavg_av_L1A45**2);

stavg_au_L4A45 = np.mean(au_L4A45[-set_min_steps:-1,:], axis=0);
stavg_av_L4A45 = np.mean(av_L4A45[-set_min_steps:-1,:], axis=0);
stavg_auu_L4A45 = np.mean(auu_L4A45[-set_min_steps:-1,:], axis=0);
stavg_avv_L4A45 = np.mean(avv_L4A45[-set_min_steps:-1,:], axis=0);
stavg_aww_L4A45 = np.mean(aww_L4A45[-set_min_steps:-1,:], axis=0);
stavg_auw_L4A45 = np.mean(auw_L4A45[-set_min_steps:-1,:], axis=0);
stavg_atxz_L4A45 = np.mean(atxz_L4A45[-set_min_steps:-1,:], axis=0);
stavg_avw_L4A45 = np.mean(avw_L4A45[-set_min_steps:-1,:], axis=0);
stavg_atyz_L4A45 = np.mean(atyz_L4A45[-set_min_steps:-1,:], axis=0);
ustar_L4A45 = ((stavg_auw_L4A45+stavg_atxz_L4A45)**2 + (stavg_avw_L4A45+stavg_atyz_L4A45)**2)**(0.25);
ustar_L4A45_max = ustar_L4A45.max()
MSpeed_L4A45 = np.sqrt(stavg_au_L4A45**2 + stavg_av_L4A45**2);

z_indx_ctop = int(np.floor(inpara_L1A0['h_canopy']/inpara_L1A0['dz']));
print('z_indx_ctop: ', z_indx_ctop);
# Out:
# z_indx_ctop:  11

# %% [markdown]
# `Siumlation parameteres`
#
# | simulation | N_1, N_2, N_3 | Canopy Height,h(m)| L_1/h, L_2/h, L_3/h |Mean angle of forcing(wrt. vine row, ccw)|
# | :---------:|:-------------:|:-----------------:|:-------------------:|:---------------------------------------:|
# | L1A0        | 96,96,48      |       2.18        |  11, 11, 4         |           0                            |
# | L4A0        | 96,96,48      |       2.18        |  11, 11, 4         |           0                            |
# | L1A45       | 96,96,48      |       2.18        |  11, 11, 4         |           45                           |
# | L4A45       | 96,96,48      |       2.18        |  11, 11, 4         |           45                           |
#
# 1,2,3 corresponds to perpendicular to vine row, vine row and vertical directions, respectively
#
# ``Row width = 0.5 m``
#
# ``Row Spaing = 1.0 m``
#
# ``Canopy drag coefficient = 0.50 ``
#
# ``n_width = 2``
#
# Averaging has been done over entire horizontal domains and calculated from code-outputs, au.bin, auw.bin, atxz.bin and so on. On time scale, all averaging has been done over last 5 minutes of a total of 20 minute simulations.

# %%
fpath_L1A0 = master_dir_L1A0 + "input/PlantDensity.ini"
lad3d_L1A0 = ld.loadField(fpath_L1A0, inpara_L1A0['Nx'], inpara_L1A0['Ny'], inpara_L1A0['Nz']);

fpath_L4A0 = master_dir_L4A0 + "input/PlantDensity.ini"
lad3d_L4A0 = ld.loadField(fpath_L4A0, inpara_L4A0['Nx'], inpara_L4A0['Ny'], inpara_L4A0['Nz']);

fpath_L1A45 = master_dir_L1A45 + "input/PlantDensity.ini"
lad3d_L1A45 = ld.loadField(fpath_L1A45, inpara_L1A45['Nx'], inpara_L4A45['Ny'], inpara_L4A0['Nz']);

fpath_L4A45 = master_dir_L4A45 + "input/PlantDensity.ini"
lad3d_L4A45 = ld.loadField(fpath_L4A45, inpara_L4A45['Nx'], inpara_L4A45['Ny'], inpara_L4A0['Nz']);

non_zero_pos = np.nonzero(lad3d_L1A0[:,10,10]);
lad_true_indx = non_zero_pos[0][3]; 
vert_last_lad_indx = len(np.nonzero(lad3d_L1A0[lad_true_indx ,10,:])[0]);
fig = plt.figure();
fig.set_size_inches(fwidth, fheight);
ax = fig.add_subplot(111);
ax.plot(lad3d_L1A0[lad_true_indx,24,:]*inpara_L1A0['h_canopy'],z_u/inpara_L1A0['h_canopy'], color='g', marker='x', markevery=4, MarkerSize=7);
ax.plot(lad3d_L4A0[lad_true_indx,24,:]*inpara_L4A0['h_canopy'],z_u/inpara_L4A0['h_canopy'], color='c', marker=r'$\bullet$',markevery=4, MarkerSize=7);
ax.plot(lad3d_L1A45[lad_true_indx,24,:]*inpara_L1A45['h_canopy'],z_u/inpara_L1A45['h_canopy'], color='b', marker=r'$\clubsuit$',markevery=4, MarkerSize=7);
ax.plot(lad3d_L4A45[lad_true_indx,24,:]*inpara_L4A45['h_canopy'],z_u/inpara_L4A45['h_canopy'], color='m', marker=r'$0$',markevery=4, MarkerSize=7);
ax.set_ylim([0, 2]);
ax.set_xlabel(r'$LAD \times h$', fontsize= axl_font_sz);
ax.set_ylabel(r'$x_3/h$', fontsize= axl_font_sz);
plt.box(on=1);
#print(lad_true_indx, vert_last_lad_indx)
LAI_1A0 = scipy.integrate.simps(lad3d_L1A0[lad_true_indx, 24,0:vert_last_lad_indx], z_u[0:vert_last_lad_indx]);
LAI_4A0 = scipy.integrate.simps(lad3d_L4A0[lad_true_indx, 24,0:vert_last_lad_indx], z_u[0:vert_last_lad_indx]);
LAI_1A0 = scipy.integrate.simps(lad3d_L1A45[lad_true_indx, 24,0:vert_last_lad_indx], z_u[0:vert_last_lad_indx]);
LAI_1A45 = scipy.integrate.simps(lad3d_L1A45[lad_true_indx, 24,0:vert_last_lad_indx], z_u[0:vert_last_lad_indx]);
LAI_4A45 = scipy.integrate.simps(lad3d_L4A45[lad_true_indx, 24,0:vert_last_lad_indx], z_u[0:vert_last_lad_indx]);
print("Leaf area index L1A0: {0:2.2f}".format(LAI_1A0));
print("Leaf area index L4A0: {0:2.2f}".format(LAI_4A0));
print("Leaf area index L1A45: {0:2.2f}".format(LAI_1A45));
print("Leaf area index L4A45: {0:2.2f}".format(LAI_4A45));

displacement_height_L1A0 = spy.integrate.simps(z_u[0:11]* ustar_L1A0[0:11]**2, z_u[0:11])/ \
                         spy.integrate.simps(ustar_L1A0[0:11]**2, z_u[0:11]);
displacement_height_L4A0 = spy.integrate.simps(z_u[0:11]* ustar_L4A0[0:11]**2, z_u[0:11])/ \
                         spy.integrate.simps(ustar_L4A0[0:11]**2, z_u[0:11]);
displacement_height_L4A45 = spy.integrate.simps(z_u[0:11]* ustar_L4A45[0:11]**2, z_u[0:11])/ \
                         spy.integrate.simps(ustar_L4A45[0:11]**2, z_u[0:11]);
displacement_height_L1A45 = spy.integrate.simps(z_u[0:11]* ustar_L1A45[0:11]**2, z_u[0:11])/ \
                         spy.integrate.simps(ustar_L1A45[0:11]**2, z_u[0:11]);    
print("Displacement Height, L1A0 : {0:2.2f}".format(displacement_height_L1A0/inpara_L1A0['h_canopy']));
print("Displacement Height, L4A0 : {0:2.2f}".format(displacement_height_L4A0/inpara_L4A0['h_canopy']));
print("Displacement Height, L1A45 : {0:2.2f}".format(displacement_height_L1A45/inpara_L1A45['h_canopy']));
print("Displacement Height, L4A45 : {0:2.2f}".format(displacement_height_L4A45/inpara_L4A45['h_canopy']));
# Out:
# Leaf area index L1A0: 1.03
# Leaf area index L4A0: 3.99
# Leaf area index L1A45: 1.03
# Leaf area index L4A45: 3.99
# Displacement Height, L1A0 : 0.71
# Displacement Height, L4A0 : 0.74
# Displacement Height, L1A45 : 0.71
# Displacement Height, L4A45 : 0.74

# %%
x = np.arange(inpara_L1A0['Nx']);
y = np.arange(inpara_L1A0['Nz']);
x = x - x[47];
y = y - y[24];
x = [i*inpara_L1A0['dx']/inpara_L1A0['h_canopy'] for i in x];
y = [i*inpara_L1A0['dz']/inpara_L1A0['h_canopy'] for i in y] ;

fig = plt.figure();
fig.set_size_inches(6, 3);
ax = fig.add_subplot(111);
ss = inpara_L1A0['h_canopy'];
pevery = 1;
colors = np.sqrt((np.mean(lad3d_L1A0, axis=1)).T[::pevery,::pevery]**2/ss, \
                np.mean(lad3d_L1A0, axis=1).T[::pevery,::pevery]**2/ss)/np.sqrt(2);
ladprof = np.mean(lad3d_L1A0, axis=1).T[::pevery,::pevery];

xx, yy = np.meshgrid(x[::pevery], y[::pevery]);
xx = np.reshape(xx, xx.size, order='c');
yy = np.reshape(yy, xx.size, order='c');
ladprof = np.reshape(ladprof/np.max(ladprof), ladprof.size, order='c');
#ax.scatter(xx,yy, c=ladprof, cmap=cm.BuGn, marker=r'o', alpha=0.75);
XX, YY = np.meshgrid(x[::pevery], y[::pevery]);
pax = ax.pcolormesh(XX.T, YY.T, lad3d_L1A0[:, 48,:], cmap=cm.BuGn);
fig.colorbar(pax);
ax.set_xlim([-6, 6]);
ax.set_xlabel(r'$x_1/h$', fontsize= axl_font_sz);
ax.set_ylabel(r'$x_3/h$', fontsize= axl_font_sz);

# %% [markdown]
# Pseudocolor plot of leaf area index on $x_1$-$x_3$ plane (all cases)

# %%
fig = plt.figure();
fig.set_size_inches(fwidth, fheight);
ax = fig.add_subplot(111);
ax.plot(time_values/60.0,ustar_L1A0_planeavg[:,z_indx_ctop]*inpara_L1A0['u_star'], color='g', marker='x', markevery=100000);
ax.plot(time_values/60.0,ustar_L4A0_planeavg[:,z_indx_ctop]*inpara_L4A0['u_star'], color='c', marker=r'$\bullet$', markevery=100000);
ax.plot(time_values/60.0,ustar_L1A45_planeavg[:,z_indx_ctop]*inpara_L1A45['u_star'], color='b', marker=r'$\clubsuit$', markevery=100000);
ax.plot(time_values/60.0,ustar_L4A45_planeavg[:,z_indx_ctop]*inpara_L4A45['u_star'], color='m', marker=r'$\bullet$', markevery=100000);
ax.set_xlabel(r't(min)', fontsize= axl_font_sz);
ax.set_ylabel(r'$\langle u_*(t) \rangle$', fontsize= axl_font_sz);
plt.box(on=1);

# %% [markdown]
# Time series of shear velocity for all cases at canopy height

# %%
fig = plt.figure();
fig.set_size_inches(fwidth, fheight);
ax = fig.add_subplot(111);
ax.plot(MSpeed_L1A0/MSpeed_L1A0[z_indx_ctop],z_w/inpara_L1A0['h_canopy'],  color='g', marker='$\times$' ,markevery=4, MarkerSize=7);
ax.plot(MSpeed_L4A0/MSpeed_L4A0[z_indx_ctop],z_w/inpara_L4A0['h_canopy'], color='c', marker=r'$\bullet$', markevery=4, MarkerSize=7);
ax.plot(MSpeed_L4A45/MSpeed_L1A45[z_indx_ctop],z_w/inpara_L1A45['h_canopy'], color='b', marker=r'$\clubsuit$', markevery=4, MarkerSize=7);
ax.plot(MSpeed_L4A45/MSpeed_L4A45[z_indx_ctop],z_w/inpara_L4A45['h_canopy'], color='m', marker=r'$o$', markevery=4, MarkerSize=7);
#ax.plot([0.0, 1.5],[1.0, 1.0],'-k', alpha=0.2);
ax.set_ylim([0, 4]);
ax.set_xlabel(r'$U/U_{h}$', fontsize= axl_font_sz);
ax.set_ylabel(r'$x_3/h$', fontsize= axl_font_sz);
plt.box(on=1);

# %% [markdown]
# Mean flow speed profile normalized by speed at canopy height. Lines with markers $\times$, $\bullet$ $\clubsuit$, and $o$ correspond to L1A0, L4A0, L1A45, and L4A45 cases, respectively.

# %%
fig = plt.figure();
fig.set_size_inches(fwidth, fheight);
ax = fig.add_subplot(111);
ax.plot(ustar_L1A0,z_w/inpara_L1A0['h_canopy'], color='g', marker='$\times$', markevery=4, MarkerSize=7);
ax.plot(ustar_L4A0,z_w/inpara_L4A0['h_canopy'], color='c', marker=r'$\bullet$',markevery=4, MarkerSize=7);
ax.plot(ustar_L1A45,z_w/inpara_L1A45['h_canopy'], color='b', marker=r'$\clubsuit$',markevery=4, MarkerSize=7);
ax.plot(ustar_L4A45,z_w/inpara_L4A45['h_canopy'], color='m', marker=r'$o$',markevery=4, MarkerSize=7);
#ax.plot([0.0, 1.2],[1.0, 1.0],'-k', alpha=0.2);
ax.set_xlabel(r'$u_{*}$', fontsize= axl_font_sz);
ax.set_ylabel(r'$x_3/h$', fontsize= axl_font_sz);
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.set_ylim([0, 2]);
plt.box(on=1);
ax.xaxis.labelpad = 10;

# %% [markdown]
# Shear velocity profile. Lines with markers $\times$, $\bullet$ $\clubsuit$, and $o$ correspond to L1A0, L4A0, L1A45, and L4A45 cases, respectively.

# %%
fig = plt.figure();
fig.set_size_inches(fwidth, fheight);
ax = fig.add_subplot(111);
ax.plot((stavg_auu_L1A0)/ustar_L1A0_max**2,z_w/inpara_L1A0['h_canopy'], color='g', marker='$\times$',markevery=4, MarkerSize=7);
ax.plot((stavg_auu_L4A0)/ustar_L4A0_max**2,z_w/inpara_L4A0['h_canopy'], color='c', marker=r'$\bullet$', markevery=4, MarkerSize=7);
ax.plot((stavg_auu_L1A45)/ustar_L1A45_max**2,z_w/inpara_L1A45['h_canopy'], color='b', marker=r'$\clubsuit$', markevery=4, MarkerSize=7);
ax.plot((stavg_auu_L4A45)/ustar_L4A45_max**2,z_w/inpara_L4A45['h_canopy'], color='m', marker=r'$o$', markevery=4, MarkerSize=7);
ax.set_xlabel(r'$(\overline{\langle (\tilde{u}_{\perp}^\prime)^2 \rangle}/u_*^2$', fontsize= axl_font_sz);
ax.set_ylabel(r'$x_3/h$', fontsize= axl_font_sz);
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.set_ylim([0, 2]);
plt.box(on=1);
ax.xaxis.labelpad = 10;

# %% [markdown]
# Profile of variance of row-perpendicular component of velocity ($u_1$). Lines with markers $\times$, $\bullet$ $\clubsuit$, and $o$ correspond to L1A0, L4A0, L1A45, and L4A45 cases, respectively.

# %%
fig = plt.figure();
fig.set_size_inches(fwidth, fheight);
ax = fig.add_subplot(111);
ax.plot((stavg_avv_L1A0)/ustar_L1A0_max**2,z_w/inpara_L1A0['h_canopy'], color='g', marker='x', markevery=4, MarkerSize=7);
ax.plot((stavg_avv_L4A0)/ustar_L4A0_max**2,z_w/inpara_L4A0['h_canopy'], color='c', marker=r'$\bullet$', markevery=4, MarkerSize=7);
ax.plot((stavg_avv_L1A45)/ustar_L1A45_max**2,z_w/inpara_L1A45['h_canopy'], color='b', marker=r'$\clubsuit$', markevery=4, MarkerSize=7);
ax.plot((stavg_avv_L4A45)/ustar_L4A45_max**2,z_w/inpara_L4A45['h_canopy'], color='m', marker=r'$o$', markevery=4, MarkerSize=7);
ax.set_xlabel(r'($\overline{\langle (\tilde{u}_{\parallel}^\prime)^2 \rangle}/u_*^2$', fontsize= axl_font_sz);
ax.set_ylabel(r'$x_3/h$', fontsize= axl_font_sz);
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.set_ylim([0, 2]);
plt.box(on=1);
ax.xaxis.labelpad = 10;

# %% [markdown]
# Profile of variance of row-parallel velocity component($u_2$). Lines with markers $\times$, $\bullet$ $\clubsuit$, and $o$ correspond to L1A0, L4A0, L1A45, and L4A45 cases, respectively.

# %%
fig = plt.figure();
fig.set_size_inches(fwidth, fheight);
ax = fig.add_subplot(111);
ax.plot((stavg_auw_L1A0+stavg_atxz_L1A0)/ustar_L1A0_max**2,z_w/inpara_L1A0['h_canopy'], color='g', marker='x', markevery=4, MarkerSize=7);
ax.plot((stavg_auw_L4A0+stavg_atxz_L4A0)/ustar_L4A0_max**2,z_w/inpara_L4A0['h_canopy'], color='c', marker=r'$\bullet$', markevery=4, MarkerSize=7);
ax.plot((stavg_auw_L1A45+stavg_atxz_L1A45)/ustar_L1A45_max**2,z_w/inpara_L1A45['h_canopy'], color='b', marker=r'$\clubsuit$', markevery=4, MarkerSize=7);
ax.plot((stavg_auw_L4A45+stavg_atxz_L4A45)/ustar_L4A45_max**2,z_w/inpara_L4A45['h_canopy'], color='m', marker=r'$o$', markevery=4, MarkerSize=7);
#ax.plot([-1.0, 0.25],[1.0, 1.0],'-k', alpha=0.2);
ax.set_xlabel(r'$(\overline{\langle u_{\perp}^\prime u_{3}^{\prime} \rangle}+\langle \tau_{\perp 3} \rangle)/u_*^2$', fontsize= axl_font_sz);
ax.set_ylabel(r'$x_3/h$', fontsize= axl_font_sz);
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.set_ylim([0, 2]);
plt.box(on=1);
ax.xaxis.labelpad = 10;

# %% [markdown]
# Momentum flux ($u_1u_3 + \tau_{13}$). Lines with markers $\times$, $\bullet$ $\clubsuit$, and $o$ correspond to L1A0, L4A0, L1A45, and L4A45 cases, respectively.

# %%
fig = plt.figure();
fig.set_size_inches(fwidth, fheight);
ax = fig.add_subplot(111);
ax.plot((stavg_avw_L1A0+stavg_atyz_L1A0)/ustar_L1A0_max**2,z_w/inpara_L1A0['h_canopy'], color='g', marker='x', markevery=4, MarkerSize=7);
ax.plot((stavg_avw_L4A0+stavg_atyz_L4A0)/ustar_L4A0_max**2,z_w/inpara_L4A0['h_canopy'], color='c', marker=r'$\bullet$', markevery=4, MarkerSize=7);
ax.plot((stavg_avw_L1A45+stavg_atyz_L1A45)/ustar_L1A45_max**2,z_w/inpara_L1A45['h_canopy'], color='b', marker=r'$\clubsuit$', markevery=4, MarkerSize=7);
ax.plot((stavg_avw_L4A45+stavg_atyz_L4A45)/ustar_L4A45_max**2,z_w/inpara_L4A45['h_canopy'], color='m', marker=r'$o$', markevery=4, MarkerSize=7);
#ax.plot([-1.0, 0.25],[1.0, 1.0],'-k', alpha=0.2);
ax.set_xlabel(r'$(\overline{\langle u_{\parallel}^\prime u_{3}^{\prime} \rangle}+\langle \tau_{\parallel 3} \rangle)/u_*^2$', fontsize= axl_font_sz);
ax.set_ylabel(r'$x_3/h$', fontsize= axl_font_sz);
ax.set_ylim([0, 2]);
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.xaxis.labelpad = 10;
plt.box(on=1);

# %% [markdown]
# Momentum flux ($u_2u_3 + \tau_{23}$). Lines with markers $\times$, $\bullet$ $\clubsuit$, and $o$ correspond to L1A0, L4A0, L1A45, and L4A45 cases, respectively.

# %%
import plot_protractor
#speed_90 = np.sqrt(uu_vrow_90**2 + vv_vrow_90**2);
plt.rc('text', usetex=True);
fig = plt.figure();
ax = fig.add_subplot(111)
fig.set_size_inches(fwidth, fheight)
ax.plot(stavg_au_L1A0/MSpeed_L1A0[z_indx_ctop],stavg_av_L1A0/MSpeed_L1A0[z_indx_ctop], color='g', marker='x', markevery=16, MarkerSize=7);
ax.plot(stavg_au_L4A0/MSpeed_L4A0[z_indx_ctop],stavg_av_L4A0/MSpeed_L4A0[z_indx_ctop],color='c', marker=r'$\bullet$', markevery=16, MarkerSize=7);
ax.plot(stavg_au_L1A45/MSpeed_L1A45[z_indx_ctop],stavg_av_L1A45/MSpeed_L1A45[z_indx_ctop],color='b', marker=r'$\clubsuit$', markevery=16, MarkerSize=7);
ax.plot(stavg_au_L4A45/MSpeed_L4A45[z_indx_ctop],stavg_av_L4A45/MSpeed_L4A45[z_indx_ctop],color='m', marker=r'$o$', markevery=16, MarkerSize=7);
plot_protractor.plot_protractor();
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.set_ylim([-0.5, 5.0]);
ax.set_xlim([-0.5, 5.0]);
ax.set_xlabel(r'$u_{\perp}/U_h$', fontsize= axl_font_sz);
ax.set_ylabel(r'$u_{\parallel}/U_h$', fontsize= axl_font_sz);
plt.box(on=1);

# %% [markdown]
# Hodograph. Lines with markers $\times$, $\bullet$ $\clubsuit$, and $o$ correspond to L1A0, L4A0, L1A45, and L4A45 cases, respectively.
